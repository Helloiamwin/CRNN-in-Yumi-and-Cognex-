# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
train_img_path = "E:\\Yumi\\data_30_11\\Image00007.JPG"
#"E:\\Yumi\\data_30_11\\Image00000.JPG"
#"E:\\Year4_Sec1\\Image_Pro\\final_exam\\data\\Image11-28-2022 - 15.33.04.523.JPG"
#img = cv2.cvtColor(cv2.imread(train_img_path), cv2.COLOR_BGR2GRAY)
img = cv2.imread(train_img_path)
img = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img = img[420:600,190:1000] #data 07-12
#height, width = img.shape

# in this dataset, we don't need to do any resize at all here.
#img = cv2.resize(img,(int(118/height*width),118))

# height, width = img.shape

# if img.shape[1] > resize_max_width:
#     resize_max_width = img.shape[1]

#img = np.pad(img, ((0,0),(0, 2167-width)), 'median') # expand pad part to tail

# YOUR PART: Blur it
img = cv2.GaussianBlur(img, (5,5), 0)

# YOUR PART: Threshold the image using adapative threshold
img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,11,5)
#img = img [790:250,70:1000]
#img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,33,5)

# %%
plt.imshow(img,cmap = 'gray') 
plt.show()

# %%
a = 0

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("E:\\Yumi\\Do_an_2\\data_7_12_light_6\\Image00048.JPG")
img = img[420:620,190:1000]

cv2.imwrite("data_7_12_cropped\\0001_abc_2{}.jpg".format(a), img)
a+=1
plt.imshow(img,cmap = 'gray') 
plt.show()

# %%
a = 0
